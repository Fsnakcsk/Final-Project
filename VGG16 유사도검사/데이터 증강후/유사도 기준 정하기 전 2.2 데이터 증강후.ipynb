# %% [markdown]
# # 필요 라이브러리 불러오기

# %% [markdown]
# ## 라이브러리 불러오기 전
# - pip install opencv-python 을 입력하여 설치하기

# %%
from keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.models import Model
import numpy as np
import pandas as pd
import cv2
from IPython.display import Image
from os import listdir as ld

# %% [markdown]
# # 필요 모델 들고오기 - VGG16

# %%
vgg_model = VGG16(weights='imagenet', include_top=False)

# %% [markdown]
# ## 마지막 컨볼루션 레이어의 출력으로 새 모델 생성

# %%
# Create a new model with the output of the last convolutional layer
model = Model(inputs=vgg_model.input, outputs=vgg_model.get_layer('block5_pool').output)

# %%
import keras.utils as utils #이미지를 불러오기 위해 필요한 package

# %%
Image('C:/Users/admin/Desktop/simpic/a.png')

# %% [markdown]
# # 기준이 될 이미지 불러오기
# - 첫 번째 이미지를 로드하고 VGG용으로 사전 처리

# %%
Image("C:\\Users\\admin\\Desktop\\새 폴더 (2)\\2배기\\s_0038_24899_408276.png")

# %%
# Load the first image and preprocess it for VGG
img1 = utils.load_img("C:\\Users\\admin\\Desktop\\새 폴더 (2)\\2배기\\s_0038_24899_408276.png", target_size=(224, 224))
img1 = utils.img_to_array(img1)
img1 = np.expand_dims(img1, axis=0)
img1 = preprocess_input(img1)

# %% [markdown]
# ## 첫 번째 이미지에서 형상 추출

# %%
# Extract features from the first image
features1 = model.predict(img1)
features1 = features1.flatten()
# Out:
# 1/1 [==============================] - 0s 394ms/step

# %% [markdown]
# # 비교 이미지(positive)불러오기

# %%
Image("C:\\Users\\admin\\Desktop\\새 폴더 (2)\\2배기\긍적\\s_0038_24883_610516.jpg")

# %%
# Load the second image and preprocess it for VGG
img2 = utils.load_img("C:\\Users\\admin\\Desktop\\새 폴더 (2)\\2배기\긍정\\s_0038_24883_610516.jpg", target_size=(224, 224))
img2 = utils.img_to_array(img2)
img2 = np.expand_dims(img2, axis=0)
img2 = preprocess_input(img2)

# %%
# Extract features from the second image
features2 = model.predict(img2)
features2 = features2.flatten()
# Out:
# 1/1 [==============================] - 0s 169ms/step

# %%
# Calculate the cosine similarity between the two feature vectors
cosine_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

# %% [markdown]
# ## positive image cosine similarity

# %%
print("Cosine similarity: ", cosine_similarity)
# Out:
# Cosine similarity:  0.27506816

# %% [markdown]
# # 비교 이미지(negative) 불러오기

# %%
Image("C:\\Users\\admin\Desktop\\새 폴더 (2)\\2배기\부정\\s_0038_24887_620467.jpg")

# %%
# Load the second image and preprocess it for VGG
img2 = utils.load_img("C:\\Users\\admin\Desktop\\새 폴더 (2)\\2배기\부정\\s_0038_24887_620467.jpg", target_size=(224, 224))
img2 = utils.img_to_array(img2)
img2 = np.expand_dims(img2, axis=0)
img2 = preprocess_input(img2)

# %%
# Extract features from the second image
features2 = model.predict(img2)
features2 = features2.flatten()
# Out:
# 1/1 [==============================] - 0s 189ms/step

# %%
# Calculate the cosine similarity between the two feature vectors
cosine_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

# %% [markdown]
# ## negative

# %%
print("Cosine similarity: ", cosine_similarity)
# Out:
# Cosine similarity:  0.32642108

# %% [markdown]
# # 함수

# %%
def cos_sim(list, mod='positive'):
    positive_sim=[]
    negative_sim=[]
    for i in (list):
        img2 = utils.load_img(i, target_size = (224, 224))
        img2 = utils.img_to_array(img2)
        img2 = np.expand_dims(img2, axis=0)
        img2 = preprocess_input(img2)
        features2 = model.predict(img2)
        features2 = features2.flatten()
        cos_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))
        if mod == 'positive':
            positive_sim.append(cos_similarity)
        elif mod == 'negative':
            negative_sim.append(cos_similarity)
        else:
            print('함수 잘못 사용함')
    if mod == 'positive':
        print('POSITIVE')
        posi_sim_df = pd.DataFrame(positive_sim)
        print('최대 유사도: %.2f, 최소 유사도: %.2f, 평균 유사도: %.2f, 중앙 유사도: %.2f' %(max(positive_sim), min(positive_sim),
                                                                   (sum(positive_sim)/len(positive_sim)), posi_sim_df.median(axis=0)))
        
        posi_sim_df.to_csv('positive.csv')
        return posi_sim_df
    else:
        print('NEGATIVE')
        nega_sim_df = pd.DataFrame(negative_sim)
        print('최대 유사도: %.2f, 최소 유사도: %.2f, 평균 유사도: %.2f, 중앙 유사도: %.2f' %(max(negative_sim), min(negative_sim),
                                                                   (sum(negative_sim)/len(negative_sim)), nega_sim_df.median(axis=0)))
        nega_sim_df.to_csv('negative.csv')
        return nega_sim_df

# %%
nega_dir = 'C:\\Users\\admin\Desktop\\새 폴더 (2)\\2배기\\부정'
posi_dir = 'C:\\Users\\admin\\Desktop\\새 폴더 (2)\\2배기\\긍정'

nega_list = [nega_dir+'\\'+f for f in(ld(nega_dir))]
posi_list = [posi_dir+'\\'+f for f in(ld(posi_dir))]

# %%
print(nega_list[0])
print(posi_list[0])
# Out:
# C:\Users\admin\Desktop\새 폴더 (2)\2배기\부정\s_0038_24774_170571.jpg
# C:\Users\admin\Desktop\새 폴더 (2)\2배기\긍정\s_0038_24883_352043.png

# %%
cos_sim(nega_list, 'negative')
# Out:
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 152ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 156ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 213ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 159ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 142ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 136ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 146ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 137ms/step
# NEGATIVE
# 최대 유사도: 0.54, 최소 유사도: 0.14, 평균 유사도: 0.25, 중앙 유사도: 0.22
#            0
# 0   0.231036
# 1   0.143448
# 2   0.210056
# 3   0.205051
# 4   0.240930
# ..       ...
# 92  0.493470
# 93  0.429040
# 94  0.404526
# 95  0.458039
# 96  0.535331
#
# [97 rows x 1 columns]

# %%
cos_sim(posi_list)
# Out:
# 1/1 [==============================] - 0s 192ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 178ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 140ms/step
# 1/1 [==============================] - 0s 151ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 176ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 157ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 154ms/step
# 1/1 [==============================] - 0s 163ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 141ms/step
# 1/1 [==============================] - 0s 152ms/step
# POSITIVE
# 최대 유사도: 0.55, 최소 유사도: 0.22, 평균 유사도: 0.36, 중앙 유사도: 0.36
#            0
# 0   0.229585
# 1   0.403054
# 2   0.278819
# 3   0.288906
# 4   0.329008
# 5   0.228136
# 6   0.449088
# 7   0.222612
# 8   0.275068
# 9   0.553047
# 10  0.365597
# 11  0.401314
# 12  0.431506
# 13  0.387984
# 14  0.441782
# 15  0.352004
# 16  0.365327
# 17  0.328926
# 18  0.421210
# 19  0.310683
# 20  0.303857
# 21  0.396664
# 22  0.514561
# 23  0.353021

# %% [markdown]
# # 완전 다른 이미지01

# %%
Image('C:/Users/admin/Desktop/simpic/6.jpg')

# %%
# Load the second image and preprocess it for VGG
img2 = image.load_img('C:/Users/admin/Desktop/simpic/6.jpg', target_size=(224, 224))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2, axis=0)
img2 = preprocess_input(img2)

# %%
# Extract features from the second image
features2 = model.predict(img2)
features2 = features2.flatten()
# Out:
# 1/1 [==============================] - 0s 136ms/step

# %%
# Calculate the cosine similarity between the two feature vectors
cosine_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

# %%
print("Cosine similarity: ", cosine_similarity)
# Out:
# Cosine similarity:  0.21409264

# %% [markdown]
# # 완전 다른 이미지 02

# %%
Image('C:/Users/admin/Desktop/simpic/8.jpg')

# %%
# Load the second image and preprocess it for VGG
img2 = image.load_img('C:/Users/admin/Desktop/simpic/8.jpg', target_size=(224, 224))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2, axis=0)
img2 = preprocess_input(img2)

# %%
# Extract features from the second image
features2 = model.predict(img2)
features2 = features2.flatten()
# Out:
# 1/1 [==============================] - 0s 134ms/step

# %%
# Calculate the cosine similarity between the two feature vectors
cosine_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

# %%
print("Cosine similarity: ", cosine_similarity)
# Out:
# Cosine similarity:  0.16533415

# %% [markdown]
# # 완전 다른 이미지03

# %%
Image('C:/Users/admin/Desktop/simpic/9.png')

# %%
# Load the second image and preprocess it for VGG
img2 = image.load_img('C:/Users/admin/Desktop/simpic/9.png', target_size=(224, 224))
img2 = image.img_to_array(img2)
img2 = np.expand_dims(img2, axis=0)
img2 = preprocess_input(img2)

# %%
# Extract features from the second image
features2 = model.predict(img2)
features2 = features2.flatten()
# Out:
# 1/1 [==============================] - 0s 310ms/step

# %%
# Calculate the cosine similarity between the two feature vectors
cosine_similarity = np.dot(features1, features2) / (np.linalg.norm(features1) * np.linalg.norm(features2))

# %%
print("Cosine similarity: ", cosine_similarity)
# Out:
# Cosine similarity:  0.14307235
